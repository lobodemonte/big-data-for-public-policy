# %% [markdown]
# Assignment 3 is an individual assignment that will test your understanding of API calls. When we created the patent class data that you can find in our shared yandex folder we queried the API too. Your exercise is to construct the same file. You don't have to this for all the years, one year is enough. Here are the specific instructions to follow
#
# * Pick one year X and create the patents data for that specific year.
# * Filter all patents that were granted in year X for which:
#   * The first named inventor is from the USA
#   * AND the first named assignee is from the USA
# * Retrieve all the fields that we have in our class data in patent_X.
#
# Keep in mind: The patents API has a limit on how many patents can be displayed on one page and when there are a lot of patents you might have to retrieve multiple pages. The overall number of patents you can retrieve is 100,000 (max page number.Xmax page entries). If you expect to end up with more patents than this you have to think about a way to reduce the query by splitting the year into subsamples.
#
# After you query the data transfer them into a data frame. Please keep in mind that you might have nested json files that you need to harmonize.
#
# * Save the data frame and submit the notebook to NYU classes
#
# You can get 10 points for this assignment if you complete the entire assignment.

# %%
# interacting with websites and web-APIs
import requests # easy way to interact with web sites and services
import json # read/write JavaScript Object Notation (JSON)

# data manipulation
import pandas as pd 
# normalize nested JSON files
from pandas.io.json import json_normalize

# %%
patent_year = 2011
per_page = 9500
max_retrieve = 100000

# %%
def get_patents_url(patent_year, per_page, page):
    base_url = 'https://www.patentsview.org/api/patents/query?'

    condition = '{{"_and":[{{"_eq":{{"patent_year":"{}"}}}}'\
        ',{{"_eq":{{"patent_firstnamed_inventor_country":"US"}}}}'\
        ',{{"_eq":{{"patent_firstnamed_assignee_country":"US"}}}}'\
        ']}}'.format(patent_year)

    options = '&o={{"per_page":"{}","page":"{}"}}'.format(per_page, page)
    
    fields = '&f=["patent_number","patent_title","patent_abstract","patent_num_cited_by_us_patents","patent_date",'\
        '"patent_firstnamed_inventor_city","patent_firstnamed_inventor_state","patent_firstnamed_inventor_latitude","patent_firstnamed_inventor_longitude",'\
        '"patent_firstnamed_assignee_city","patent_firstnamed_assignee_state","patent_firstnamed_assignee_latitude","patent_firstnamed_assignee_longitude",'\
        '"inventor_first_name","inventor_last_name",'\
        '"app_date","assignee_organization"'\
        ']'
    
    query = 'q={}{}{}'.format(condition, options, fields)
    return base_url + query

# %%
cols = ["patent_number","patent_title","patent_abstract","patent_num_cited_by_us_patents","patent_date",
        "patent_firstnamed_inventor_city","patent_firstnamed_inventor_state","patent_firstnamed_inventor_latitude","patent_firstnamed_inventor_longitude",
        "patent_firstnamed_assignee_city","patent_firstnamed_assignee_state","patent_firstnamed_assignee_latitude","patent_firstnamed_assignee_longitude"
       ]

cols3 = ["patent_number","patent_title"]

def normalize_json_response(json_response):
    if len(json_response['patents']) > 0:
        inventors_norm = pd.json_normalize(json_response['patents'], record_path='inventors', 
                                    meta=cols3).drop(["inventor_key_id"], axis=1) 
        assignees_norm = pd.json_normalize(json_response['patents'], record_path='assignees',
                                    meta=cols3).drop(["assignee_key_id"], axis=1) 
        apps_norm = pd.json_normalize(json_response['patents'], record_path='applications', 
                                    meta=cols3).drop(['app_id'], axis=1) 
        all_merged = pd.DataFrame(json_response['patents'])[cols]

        all_merged = pd.merge(all_merged, inventors_norm, how='left', left_on=cols3, right_on=cols3)
        all_merged = pd.merge(all_merged, assignees_norm, how='left', left_on=cols3, right_on=cols3)
        all_merged = pd.merge(all_merged,   apps_norm,    how='left', left_on=cols3, right_on=cols3)
        
        all_merged = all_merged.drop_duplicates(cols, keep='first')

        return all_merged
    return None

def execute_query(url):
    response = requests.get(url)
    if (response.status_code != 200):
        print(response.content, response.content)
        raise Exception(response.content)
    return response.json()

def get_patents(patent_year, per_page):
    patents = pd.DataFrame()
    page = 1
    
    url = get_patents_url(patent_year, per_page, page)
    print("Query #{}: {}".format(page, url))
    json_response = execute_query(url)
    
    total = json_response['total_patent_count']
    if total >= max_retrieve:
        pring("Warning total patents {} exceeds {}".format(total, max_retrieve))
        
    print("Total Number of Records: ", total)

    patents = patents.append(normalize_json_response(json_response))
  
    print("Number of Records collected: ",len(patents))

    while (json_response['count'] > 0) and ((len(patents)/total) < 1):
        page += 1
        url = get_patents_url(patent_year, per_page, page)
        print("Query #{}: {}".format(page, url))
        json_response = execute_query(url)
        patents = patents.append(normalize_json_response(json_response))
        print("Number of Records found: ", len(json_response['patents']), " collected so far: ", len(patents))
        
    
    return patents

# %%
patents_2011 = get_patents(patent_year, per_page)
# Out:
# Query #1: https://www.patentsview.org/api/patents/query?q={"_and":[{"_eq":{"patent_year":"2011"}},{"_eq":{"patent_firstnamed_inventor_country":"US"}},{"_eq":{"patent_firstnamed_assignee_country":"US"}}]}&o={"per_page":"9500","page":"1"}&f=["patent_number","patent_title","patent_abstract","patent_num_cited_by_us_patents","patent_date","patent_firstnamed_inventor_city","patent_firstnamed_inventor_state","patent_firstnamed_inventor_latitude","patent_firstnamed_inventor_longitude","patent_firstnamed_assignee_city","patent_firstnamed_assignee_state","patent_firstnamed_assignee_latitude","patent_firstnamed_assignee_longitude","inventor_first_name","inventor_last_name","app_date","assignee_organization"]
# Total Number of Records:  99250
# Number of Records collected:  9500
# Query #2: https://www.patentsview.org/api/patents/query?q={"_and":[{"_eq":{"patent_year":"2011"}},{"_eq":{"patent_firstnamed_inventor_country":"US"}},{"_eq":{"patent_firstnamed_assignee_country":"US"}}]}&o={"per_page":"9500","page":"2"}&f=["patent_number","patent_title","patent_abstract","patent_num_cited_by_us_patents","patent_date","patent_firstnamed_inventor_city","patent_firstnamed_inventor_state","patent_firstnamed_inventor_latitude","patent_firstnamed_inventor_longitude","patent_firstnamed_assignee_city","patent_firstnamed_assignee_state","patent_firstnamed_assignee_latitude","patent_firstnamed_assignee_longitude","inventor_first_name","inventor_last_name","app_date","assignee_organization"]
# Number of Records found:  9500  collected so far:  19000
# Query #3: https://www.patentsview.org/api/patents/query?q={"_and":[{"_eq":{"patent_year":"2011"}},{"_eq":{"patent_firstnamed_inventor_country":"US"}},{"_eq":{"patent_firstnamed_assignee_country":"US"}}]}&o={"per_page":"9500","page":"3"}&f=["patent_number","patent_title","patent_abstract","patent_num_cited_by_us_patents","patent_date","patent_firstnamed_inventor_city","patent_firstnamed_inventor_state","patent_firstnamed_inventor_latitude","patent_firstnamed_inventor_longitude","patent_firstnamed_assignee_city","patent_firstnamed_assignee_state","patent_firstnamed_assignee_latitude","patent_firstnamed_assignee_longitude","inventor_first_name","inventor_last_name","app_date","assignee_organization"]
# Number of Records found:  9500  collected so far:  28500
# Query #4: https://www.patentsview.org/api/patents/query?q={"_and":[{"_eq":{"patent_year":"2011"}},{"_eq":{"patent_firstnamed_inventor_country":"US"}},{"_eq":{"patent_firstnamed_assignee_country":"US"}}]}&o={"per_page":"9500","page":"4"}&f=["patent_number","patent_title","patent_abstract","patent_num_cited_by_us_patents","patent_date","patent_firstnamed_inventor_city","patent_firstnamed_inventor_state","patent_firstnamed_inventor_latitude","patent_firstnamed_inventor_longitude","patent_firstnamed_assignee_city","patent_firstnamed_assignee_state","patent_firstnamed_assignee_latitude","patent_firstnamed_assignee_longitude","inventor_first_name","inventor_last_name","app_date","assignee_organization"]
# Number of Records found:  9500  collected so far:  38000
# Query #5: https://www.patentsview.org/api/patents/query?q={"_and":[{"_eq":{"patent_year":"2011"}},{"_eq":{"patent_firstnamed_inventor_country":"US"}},{"_eq":{"patent_firstnamed_assignee_country":"US"}}]}&o={"per_page":"9500","page":"5"}&f=["patent_number","patent_title","patent_abstract","patent_num_cited_by_us_patents","patent_date","patent_firstnamed_inventor_city","patent_firstnamed_inventor_state","patent_firstnamed_inventor_latitude","patent_firstnamed_inventor_longitude","patent_firstnamed_assignee_city","patent_firstnamed_assignee_state","patent_firstnamed_assignee_latitude","patent_firstnamed_assignee_longitude","inventor_first_name","inventor_last_name","app_date","assignee_organization"]
# Number of Records found:  9500  collected so far:  47500
# Query #6: https://www.patentsview.org/api/patents/query?q={"_and":[{"_eq":{"patent_year":"2011"}},{"_eq":{"patent_firstnamed_inventor_country":"US"}},{"_eq":{"patent_firstnamed_assignee_country":"US"}}]}&o={"per_page":"9500","page":"6"}&f=["patent_number","patent_title","patent_abstract","patent_num_cited_by_us_patents","patent_date","patent_firstnamed_inventor_city","patent_firstnamed_inventor_state","patent_firstnamed_inventor_latitude","patent_firstnamed_inventor_longitude","patent_firstnamed_assignee_city","patent_firstnamed_assignee_state","patent_firstnamed_assignee_latitude","patent_firstnamed_assignee_longitude","inventor_first_name","inventor_last_name","app_date","assignee_organization"]
# Number of Records found:  9500  collected so far:  57000
# Query #7: https://www.patentsview.org/api/patents/query?q={"_and":[{"_eq":{"patent_year":"2011"}},{"_eq":{"patent_firstnamed_inventor_country":"US"}},{"_eq":{"patent_firstnamed_assignee_country":"US"}}]}&o={"per_page":"9500","page":"7"}&f=["patent_number","patent_title","patent_abstract","patent_num_cited_by_us_patents","patent_date","patent_firstnamed_inventor_city","patent_firstnamed_inventor_state","patent_firstnamed_inventor_latitude","patent_firstnamed_inventor_longitude","patent_firstnamed_assignee_city","patent_firstnamed_assignee_state","patent_firstnamed_assignee_latitude","patent_firstnamed_assignee_longitude","inventor_first_name","inventor_last_name","app_date","assignee_organization"]
# Number of Records found:  9500  collected so far:  66500
# Query #8: https://www.patentsview.org/api/patents/query?q={"_and":[{"_eq":{"patent_year":"2011"}},{"_eq":{"patent_firstnamed_inventor_country":"US"}},{"_eq":{"patent_firstnamed_assignee_country":"US"}}]}&o={"per_page":"9500","page":"8"}&f=["patent_number","patent_title","patent_abstract","patent_num_cited_by_us_patents","patent_date","patent_firstnamed_inventor_city","patent_firstnamed_inventor_state","patent_firstnamed_inventor_latitude","patent_firstnamed_inventor_longitude","patent_firstnamed_assignee_city","patent_firstnamed_assignee_state","patent_firstnamed_assignee_latitude","patent_firstnamed_assignee_longitude","inventor_first_name","inventor_last_name","app_date","assignee_organization"]
# Number of Records found:  9500  collected so far:  76000
# Query #9: https://www.patentsview.org/api/patents/query?q={"_and":[{"_eq":{"patent_year":"2011"}},{"_eq":{"patent_firstnamed_inventor_country":"US"}},{"_eq":{"patent_firstnamed_assignee_country":"US"}}]}&o={"per_page":"9500","page":"9"}&f=["patent_number","patent_title","patent_abstract","patent_num_cited_by_us_patents","patent_date","patent_firstnamed_inventor_city","patent_firstnamed_inventor_state","patent_firstnamed_inventor_latitude","patent_firstnamed_inventor_longitude","patent_firstnamed_assignee_city","patent_firstnamed_assignee_state","patent_firstnamed_assignee_latitude","patent_firstnamed_assignee_longitude","inventor_first_name","inventor_last_name","app_date","assignee_organization"]
# Number of Records found:  9500  collected so far:  85500
# Query #10: https://www.patentsview.org/api/patents/query?q={"_and":[{"_eq":{"patent_year":"2011"}},{"_eq":{"patent_firstnamed_inventor_country":"US"}},{"_eq":{"patent_firstnamed_assignee_country":"US"}}]}&o={"per_page":"9500","page":"10"}&f=["patent_number","patent_title","patent_abstract","patent_num_cited_by_us_patents","patent_date","patent_firstnamed_inventor_city","patent_firstnamed_inventor_state","patent_firstnamed_inventor_latitude","patent_firstnamed_inventor_longitude","patent_firstnamed_assignee_city","patent_firstnamed_assignee_state","patent_firstnamed_assignee_latitude","patent_firstnamed_assignee_longitude","inventor_first_name","inventor_last_name","app_date","assignee_organization"]
# Number of Records found:  9500  collected so far:  95000
# Query #11: https://www.patentsview.org/api/patents/query?q={"_and":[{"_eq":{"patent_year":"2011"}},{"_eq":{"patent_firstnamed_inventor_country":"US"}},{"_eq":{"patent_firstnamed_assignee_country":"US"}}]}&o={"per_page":"9500","page":"11"}&f=["patent_number","patent_title","patent_abstract","patent_num_cited_by_us_patents","patent_date","patent_firstnamed_inventor_city","patent_firstnamed_inventor_state","patent_firstnamed_inventor_latitude","patent_firstnamed_inventor_longitude","patent_firstnamed_assignee_city","patent_firstnamed_assignee_state","patent_firstnamed_assignee_latitude","patent_firstnamed_assignee_longitude","inventor_first_name","inventor_last_name","app_date","assignee_organization"]
# Number of Records found:  4250  collected so far:  99250

# %%
patents_2011 = patents_2011.rename(columns={
    'inventor_first_name': 'patent_firstnamed_inventor_name_first', 
    'inventor_last_name': 'patent_firstnamed_inventor_name_last',
    'assignee_organization': 'patent_firstnamed_assignee_organization'
})

# %%
cols_orig = ["patent_number","patent_title","patent_abstract","patent_num_cited_by_us_patents","patent_date",
             "app_date","patent_firstnamed_inventor_name_first","patent_firstnamed_inventor_name_last",
             "patent_firstnamed_inventor_city","patent_firstnamed_inventor_state","patent_firstnamed_inventor_latitude",
             "patent_firstnamed_inventor_longitude","patent_firstnamed_assignee_organization",
             "patent_firstnamed_assignee_city","patent_firstnamed_assignee_state","patent_firstnamed_assignee_latitude",
             "patent_firstnamed_assignee_longitude"
]
patents_2011 = patents_2011[cols_orig]

# %%
patents_2011
# Out:
#       patent_number                                       patent_title  \
# 0           7861318                Pad wearable over articulated joint
# 3           7861319                 Garment with enhanced knee support
# 4           7861321     Sports glove having protective knuckle segment
# 5           7861330                        Universal toilet tank lever
# 8           7861331             Reduced water consumption flush toilet
# ...             ...                                                ...
# 10543       RE43045  Multi-chamber MOCVD growth apparatus for high ...
# 10544       RE43047            MMS based photo album publishing system
# 10545       RE43048  Ultrasonic diagnostic imaging with harmonic co...
# 10547       RE43049  Rigidly-linked articulating wrist with decoupl...
# 10548       RE43051  Enabling a service provider to provide intrane...
#
#                                          patent_abstract  \
# 0      A pad, such as a knee, elbow, or shoulder pad,...
# 3      The present invention relates to a garment wit...
# 4      A protective sports glove that includes a prot...
# 5      A toilet tank lever assembly may be mounted in...
# 8      A reduced water consumption flush toilet for a...
# ...                                                  ...
# 10543  In one embodiment the present invention is a m...
# 10544  An MMS publishing system comprises a managemen...
# 10545  Apparatus and methods are disclosed for the de...
# 10547  The present invention is a device having a rig...
# 10548  A method and system allows a service provider ...
#
#       patent_num_cited_by_us_patents patent_date    app_date  \
# 0                                  0  2011-01-04  2007-01-29
# 3                                 30  2011-01-04  2009-03-05
# 4                                  9  2011-01-04  2008-03-19
# 5                                  3  2011-01-04  2006-04-17
# 8                                  8  2011-01-04  2003-11-26
# ...                              ...         ...         ...
# 10543                              0  2011-12-27  2010-05-05
# 10544                              0  2011-12-27  2009-11-24
# 10545                              0  2011-12-27  2000-01-11
# 10547                             19  2011-12-27  2002-06-07
# 10548                             10  2011-12-27  2007-09-19
#
#       patent_firstnamed_inventor_name_first  \
# 0                                William L.
# 3                               Michael Ray
# 4                                Matthew M.
# 5                                     Iosif
# 8                                    George
# ...                                     ...
# 10543                                 David
# 10544                              Vinod V.
# 10545                          Juin-Jet Jet
# 10547                         Kenneth Wayne
# 10548                              Peter A.
#
#       patent_firstnamed_inventor_name_last patent_firstnamed_inventor_city  \
# 0                            Grilliot, Jr.                          Dayton
# 3                                    Torry                         Edwards
# 4                               Winningham                       Royal Oak
# 5                                    Manga                       Charlotte
# 8                                    Grech                     Garden City
# ...                                    ...                             ...
# 10543                              Emerson                     Chapel Hill
# 10544                         Valloppillil                     Foster City
# 10545                                Hwang                   Mercer Island
# 10547                                Grace                          Goleta
# 10548                               Newman                   Mountain View
#
#       patent_firstnamed_inventor_state patent_firstnamed_inventor_latitude  \
# 0                                   OH                             39.7589
# 3                                   CO                              39.645
# 4                                   MI                             42.4894
# 5                                   NC                             35.2269
# 8                                   MI                             42.3256
# ...                                ...                                 ...
# 10543                               NC                             35.9131
# 10544                               CA                             37.5586
# 10545                               WA                             47.5708
# 10547                               CA                             34.4358
# 10548                               CA                             37.3861
#
#       patent_firstnamed_inventor_longitude  \
# 0                                 -84.1917
# 3                                 -106.594
# 4                                 -83.1447
# 5                                 -80.8433
# 8                                 -83.3311
# ...                                    ...
# 10543                             -79.0561
# 10544                              -122.27
# 10545                             -122.221
# 10547                             -119.827
# 10548                             -122.083
#
#       patent_firstnamed_assignee_organization patent_firstnamed_assignee_city  \
# 0         Morning Pride Manufacturing, L.L.C.                          Dayton
# 3                              AlignMed, Inc.                      Scottsdale
# 4                        Warrior Sports, Inc.                          Warren
# 5                             Brasstech, Inc.                       Santa Ana
# 8                        Thetford Corporation                       Ann Arbor
# ...                                       ...                             ...
# 10543                              Cree, Inc.                          Durham
# 10544                   Openwave Systems Inc.                    Redwood City
# 10545  Advanced Technology Laboratories, Inc.                         Bothell
# 10547     Intuitive Surgical Operations, Inc.                       Sunnyvale
# 10548       Digital Asset Enterprises, L.L.C.                      Wilmington
#
#       patent_firstnamed_assignee_state patent_firstnamed_assignee_latitude  \
# 0                                   OH                             39.7589
# 3                                   AZ                             33.5092
# 4                                   MI                             42.4775
# 5                                   CA                             33.7456
# 8                                   MI                             42.2708
# ...                                ...                                 ...
# 10543                               NC                             35.9939
# 10544                               CA                             37.4853
# 10545                               WA                             47.7625
# 10547                               CA                             37.3689
# 10548                               DE                             39.7458
#
#       patent_firstnamed_assignee_longitude
# 0                                 -84.1917
# 3                                 -111.898
# 4                                 -83.0278
# 5                                 -117.867
# 8                                 -83.7264
# ...                                    ...
# 10543                             -78.8989
# 10544                             -122.235
# 10545                             -122.204
# 10547                             -122.035
# 10548                             -75.5469
#
# [99250 rows x 17 columns]
