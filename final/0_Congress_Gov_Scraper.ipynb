# %%
import json
import re
import requests
import pandas as pd 
import numpy as np
import urllib
from bs4 import BeautifulSoup

# %%
congress_numbers = [111,112,113,114,115,116]
page_size = 250

# %%
def get_congress_url(congress_numbers, page_size, page):
    congress_q_str = "{" + '"congress":[{}]'.format(','.join('"{0}"'.format(num) for num in congress_numbers)) + "}"
    params= {
        "q": congress_q_str,
        "pageSize" : page_size,
        "page" : page,
        "searchResultViewType": "expanded",
        "KWICView": "true"
    }
    actual_params = urllib.parse.urlencode(params, safe='{}:[]')
    return "https://www.congress.gov/members?{}".format(actual_params)

def get_num_pages(soup):
    page_num_element = soup.find("div", {"class": "basic-search-tune-number"}).find("div", {"class": "pagination"}).find("span", {"class": "results-number"}).text
    page_num_raw = [int(s) for s in page_num_element.split() if s.isdigit()]
    return int(page_num_raw[0])

# %%
def extract_member_name_url(entry):
    result_heading = entry.find("span", {"class": "result-heading"})
    member_name = result_heading.text
    if "Representative" in member_name:
        member_name = member_name.replace("Representative", "").strip()

    elif "Senator" in member_name:
        member_name = member_name.replace("Senator", "").strip()
    
    url = result_heading.a['href']
    return [member_name, url]   

def extract_congress_members(congress_list):
    members = []
    for entry in congress_list:
        member = {}
        [member["name"], member["url"]] = extract_member_name_url(entry)
        
        members.append(member)
    return members

# %%
congress_url = get_congress_url(congress_numbers, page_size, 1)
print("Congress URL: ", congress_url)

response = requests.get(congress_url).text
soup = BeautifulSoup(response, "html.parser")

num_pages = get_num_pages(soup)
print("Number of result pages: ", num_pages)
# Out:
# Congress URL:  https://www.congress.gov/members?q={%22congress%22:[%22111%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22]}&pageSize=250&page=1&searchResultViewType=expanded&KWICView=true
# Number of result pages:  5

# %%
#Now that we know how many pages we'll scrape, we can start scraping
congress_url = get_congress_url(congress_numbers, page_size, 1)
print("Congress URL: ", congress_url)

response = requests.get(congress_url).text
soup = BeautifulSoup(response, "html.parser")

#We need the number of pages we will need to scrape
num_pages = get_num_pages(soup)
print("Number of result pages: ", num_pages)

all_members = []
for page in range(1, num_pages+1):
    congress_url = get_congress_url(congress_numbers, page_size, page)
    print("Congress URL: ", congress_url)
    
    response = requests.get(congress_url).text
    soup = BeautifulSoup(response, "html.parser")
    
    congress_list = soup.find("ol", {"class": "basic-search-results-lists"}).find_all("li", {"class": "expanded"})

    print("Page Size: {}, Members found: {}".format(page_size, len(congress_list)))

    members = extract_congress_members(congress_list)
    print("Extracted {} congressional entries from Page {}".format(len(members), page))
    all_members.extend(members)
# Out:
# Congress URL:  https://www.congress.gov/members?q={%22congress%22:[%22111%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22]}&pageSize=250&page=1&searchResultViewType=expanded&KWICView=true
# Page Size: 250, Members found: 250
# Extracted 250 congressional entries from Page 1
# Congress URL:  https://www.congress.gov/members?q={%22congress%22:[%22111%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22]}&pageSize=250&page=2&searchResultViewType=expanded&KWICView=true
# Page Size: 250, Members found: 250
# Extracted 250 congressional entries from Page 2
# Congress URL:  https://www.congress.gov/members?q={%22congress%22:[%22111%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22]}&pageSize=250&page=3&searchResultViewType=expanded&KWICView=true
# Page Size: 250, Members found: 250
# Extracted 250 congressional entries from Page 3
# Congress URL:  https://www.congress.gov/members?q={%22congress%22:[%22111%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22]}&pageSize=250&page=4&searchResultViewType=expanded&KWICView=true
# Page Size: 250, Members found: 250
# Extracted 250 congressional entries from Page 4
# Congress URL:  https://www.congress.gov/members?q={%22congress%22:[%22111%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22]}&pageSize=250&page=5&searchResultViewType=expanded&KWICView=true
# Page Size: 250, Members found: 10
# Extracted 10 congressional entries from Page 5

# %%
congress_members_urls = pd.DataFrame(all_members)
congress_members_urls.drop_duplicates(ignore_index=True, inplace=True)
congress_members_urls.head()
# Out:
#                  name                                                url
# 0   Abercrombie, Neil  https://www.congress.gov/member/neil-abercromb...
# 1  Abraham, Ralph Lee  https://www.congress.gov/member/ralph-abraham/...
# 2   Ackerman, Gary L.  https://www.congress.gov/member/gary-ackerman/...
# 3      Adams, Alma S.  https://www.congress.gov/member/alma-adams/A00...
# 4        Adams, Sandy  https://www.congress.gov/member/sandy-adams/A0...

# %%
def parse_profile(soup):
    results = []

    profile = soup.find("div", {"class": "overview-member-column-profile member_profile"})
    term_table = profile.find("table", {"class": "standard01 lateral01"})
    party_table = profile.find("table", {"class": "standard01 nomargin"})

    data = []
    temp = []
    for row in party_table.find_all("tr"):
        col = row.find('td').text.strip()
        temp.append(col)
    party = temp[-1]

    data = []
    for row in term_table.find_all("tr"):
        cols = row.find_all('td')
        cols = [ele.text.strip() for ele in cols]
        res = [ele for ele in cols if ele]
        if res:
            state = res[0]
            if len(res) == 2: #senate
                district = "N/A"
                info = res[1].split(":")
            elif len(res) == 3:
                district = res[1]
                info = res[2].split(":")

            if district == "--":
                district = 0
            
            chamber = info[0]

            years_str = info[1][info[1].find("(")+1:info[1].find(")")]
            years = years_str.split("-")
            if len(years) == 1:
                start = years[0]
                end = years[0]
            if len(years) == 2:
                start = years[0]
                end = years[1]
            if end == 'Present':
                end = np.inf
            results.append([party, state, district, chamber, start, end])
    return results

# %%
# Now we will fetch the profile of each representative and senator and parse it for the information we need
# Takes a bit of time
columns=['name','url','party','state','district','chamber', 'start', 'end']
congress_member_info = pd.DataFrame()
for index, row in congress_members_urls.iterrows():
    name = row['name']
    url = row['url']
    print(name)
    response = requests.get(url).text
    soup = BeautifulSoup(response, "html.parser")
    terms = parse_profile(soup)
    for term in terms:
        to_add = [name,url]
        to_add.extend(term)
        to_add = pd.Series(to_add, columns)
        congress_member_info = congress_member_info.append([to_add], ignore_index=True)
# Out:
# Abercrombie, Neil
# Abraham, Ralph Lee
# Ackerman, Gary L.
# Adams, Alma S.
# Adams, Sandy
# Aderholt, Robert B.
# Adler, John H.
# Aguilar, Pete
# Akaka, Daniel K.
# Akin, W. Todd
# Alexander, Lamar
# Alexander, Rodney
# Allen, Rick W.
# Allred, Colin Z.
# Altmire, Jason
# Amash, Justin
# Amodei, Mark E.
# Andrews, Robert E.
# Arcuri, Michael A.
# Armstrong, Kelly
# Arrington, Jodey C.
# Ashford, Brad
# Austria, Steve
# Axne, Cynthia
# Ayotte, Kelly
# Babin, Brian
# Baca, Joe
# Bachmann, Michele
# Bachus, Spencer
# Bacon, Don
# Baird, Brian
# Baird, James R.
# Balderson, Troy
# Baldwin, Tammy
# Banks, Jim
# Barber, Ron
# Barletta, Lou
# Barr, Andy
# Barragan, Nanette Diaz
# Barrasso, John
# Barrett, J. Gresham
# Barrow, John
# Bartlett, Roscoe G.
# Barton, Joe
# Bass, Charles F.
# Bass, Karen
# Baucus, Max
# Bayh, Evan
# Bean, Melissa L.
# Beatty, Joyce
# Becerra, Xavier
# Begich, Mark
# Benishek, Dan
# Bennet, Michael F.
# Bennett, Robert F.
# Bentivolio, Kerry L.
# Bera, Ami
# Berg, Rick
# Bergman, Jack
# Berkley, Shelley
# Berman, Howard L.
# Berry, Marion
# Beyer, Donald S., Jr.
# Biden, Joseph R., Jr.
# Biggert, Judy
# Biggs, Andy
# Bilbray, Brian P.
# Bilirakis, Gus M.
# Bingaman, Jeff
# Bishop, Dan
# Bishop, Mike
# Bishop, Rob
# Bishop, Sanford D., Jr.
# Bishop, Timothy H.
# Black, Diane
# Blackburn, Marsha
# Blum, Rod
# Blumenauer, Earl
# Blumenthal, Richard
# Blunt Rochester, Lisa
# Blunt, Roy
# Boccieri, John A.
# Boehner, John A.
# Bonamici, Suzanne
# Bond, Christopher S.
# Bonner, Jo
# Bono Mack, Mary
# Booker, Cory A.
# Boozman, John
# Bordallo, Madeleine Z.
# Boren, Dan
# Bost, Mike
# Boswell, Leonard L.
# Boucher, Rick
# Boustany, Charles W., Jr.
# Boxer, Barbara
# Boyd, Allen
# Boyle, Brendan F.
# Brady, Kevin
# Brady, Robert A.
# Braley, Bruce L.
# Brat, Dave
# Braun, Mike
# Bridenstine, Jim
# Bright, Bobby
# Brindisi, Anthony
# Brooks, Mo
# Brooks, Susan W.
# Broun, Paul C.
# Brown, Anthony G.
# Brown, Corrine
# Brown, Henry E., Jr.
# Brown, Scott P.
# Brown, Sherrod
# Brown-Waite, Ginny
# Brownback, Sam
# Brownley, Julia
# Buchanan, Vern
# Buck, Ken
# Bucshon, Larry
# Budd, Ted
# Buerkle, Ann Marie
# Bunning, Jim
# Burchett, Tim
# Burgess, Michael C.
# Burr, Richard
# Burris, Roland
# Burton, Dan
# Bustos, Cheri
# Butterfield, G. K.
# Buyer, Steve
# Byrd, Robert C.
# Byrne, Bradley
# Calvert, Ken
# Camp, Dave
# Campbell, John
# Canseco, Francisco "Quico"
# Cantor, Eric
# Cantwell, Maria
# Cao, Anh "Joseph"
# Capito, Shelley Moore
# Capps, Lois
# Capuano, Michael E.
# Carbajal, Salud O.
# Cardenas, Tony
# Cardin, Benjamin L.
# Cardoza, Dennis A.
# Carnahan, Russ
# Carney, Christopher P.
# Carney, John C., Jr.
# Carper, Thomas R.
# Carson, Andre
# Carter, Earl L. "Buddy"
# Carter, John R.
# Cartwright, Matt
# Case, Ed
# Casey, Robert P., Jr.
# Cassidy, Bill
# Casten, Sean
# Castle, Michael N.
# Castor, Kathy
# Castro, Joaquin
# Chabot, Steve
# Chaffetz, Jason
# Chambliss, Saxby
# Chandler, Ben
# Cheney, Liz
# Chiesa, Jeff
# Childers, Travis
# Christensen, Donna M.
# Chu, Judy
# Cicilline, David N.
# Cisneros, Gilbert Ray, Jr.
# Clark, Katherine M.
# Clarke, Hansen
# Clarke, Yvette D.
# Clawson, Curt
# Clay, Wm. Lacy
# Cleaver, Emanuel
# Cline, Ben
# Clinton, Hillary Rodham
# Cloud, Michael
# Clyburn, James E.
# Coats, Daniel
# Coble, Howard
# Coburn, Tom
# Cochran, Thad
# Coffman, Mike
# Cohen, Steve
# Cole, Tom
# Collins, Chris
# Collins, Doug
# Collins, Susan M.
# Comer, James
# Comstock, Barbara
# Conaway, K. Michael
# Connolly, Gerald E.
# Conrad, Kent
# Conyers, John, Jr.
# Cook, Paul
# Coons, Christopher A.
# Cooper, Jim
# Corker, Bob
# Cornyn, John
# Correa, J. Luis
# Cortez Masto, Catherine
# Costa, Jim
# Costello, Jerry F.
# Costello, Ryan A.
# Cotton, Tom
# Courtney, Joe
# Cowan, William M.
# Cox, TJ
# Craig, Angie
# Cramer, Kevin
# Crapo, Mike
# Cravaack, Chip
# Crawford, Eric A. "Rick"
# Crenshaw, Ander
# Crenshaw, Dan
# Crist, Charlie
# Critz, Mark S.
# Crow, Jason
# Crowley, Joseph
# Cruz, Ted
# Cuellar, Henry
# Culberson, John Abney
# Cummings, Elijah E.
# Cunningham, Joe
# Curbelo, Carlos
# Curson, David Alan
# Curtis, John R.
# Dahlkemper, Kathleen A.
# Daines, Steve
# Davids, Sharice
# Davidson, Warren
# Davis, Artur
# Davis, Danny K.
# Davis, Geoff
# Davis, Lincoln
# Davis, Rodney
# Davis, Susan A.
# Deal, Nathan
# Dean, Madeleine
# DeFazio, Peter A.
# DeGette, Diana
# Delahunt, Bill
# Delaney, John K.
# DeLauro, Rosa L.
# DelBene, Suzan K.
# Delgado, Antonio
# Demings, Val Butler
# DeMint, Jim
# Denham, Jeff
# Dent, Charles W.
# DeSantis, Ron
# DeSaulnier, Mark
# DesJarlais, Scott
# Deutch, Theodore E.
# Diaz-Balart, Lincoln
# Diaz-Balart, Mario
# Dicks, Norman D.
# Dingell, Debbie
# Dingell, John D.
# Djou, Charles K.
# Dodd, Christopher J.
# Doggett, Lloyd
# Dold, Robert J.
# Donnelly, Joe
# Donovan, Daniel M., Jr.
# Dorgan, Byron L.
# Doyle, Michael F.
# Dreier, David
# Driehaus, Steve
# Duckworth, Tammy
# Duffy, Sean P.
# Duncan, Jeff
# Duncan, John J., Jr.
# Dunn, Neal P.
# Durbin, Richard J.
# Edwards, Chet
# Edwards, Donna F.
# Ehlers, Vernon J.
# Ellison, Keith
# Ellmers, Renee L.
# Ellsworth, Brad
# Emerson, Jo Ann
# Emmer, Tom
# Engel, Eliot L.
# Ensign, John
# Enyart, William L.
# Enzi, Michael B.
# Ernst, Joni
# Escobar, Veronica
# Eshoo, Anna G.
# Espaillat, Adriano
# Estes, Ron
# Esty, Elizabeth H.
# Etheridge, Bob
# Evans, Dwight
# Faleomavaega, Eni F. H.
# Fallin, Mary
# Farenthold, Blake
# Farr, Sam
# Faso, John J.
# Fattah, Chaka
# Feingold, Russell D.
# Feinstein, Dianne
# Ferguson, A. Drew, IV
# Filner, Bob
# Fincher, Stephen Lee
# Finkenauer, Abby
# Fischer, Deb
# Fitzpatrick, Brian K.
# Fitzpatrick, Michael G.
# Flake, Jeff
# Fleischmann, Charles J. "Chuck"
# Fleming, John
# Fletcher, Lizzie
# Flores, Bill
# Forbes, J. Randy
# Fortenberry, Jeff
# Foster, Bill
# Foxx, Virginia
# Frank, Barney
# Frankel, Lois
# Franken, Al
# Franks, Trent
# Frelinghuysen, Rodney P.
# Fudge, Marcia L.
# Fulcher, Russ
# Gabbard, Tulsi
# Gaetz, Matt
# Gallagher, Mike
# Gallegly, Elton
# Gallego, Pete P.
# Gallego, Ruben
# Garamendi, John
# Garcia, Jesus G. "Chuy"
# Garcia, Joe
# Garcia, Sylvia R.
# Gardner, Cory
# Garrett, Scott
# Garrett, Thomas A., Jr.
# Gerlach, Jim
# Gianforte, Greg
# Gibbs, Bob
# Gibson, Christopher P.
# Giffords, Gabrielle
# Gillibrand, Kirsten E.
# Gingrey, Phil
# Gohmert, Louie
# Golden, Jared F.
# Gomez, Jimmy
# Gonzalez, Anthony
# Gonzalez, Charles A.
# Gonzalez, Vicente
# Resident Commissioner Gonzalez-Colon, Jenniffer
# Gooden, Lance
# Goodlatte, Bob
# Goodwin, Carte Patrick
# Gordon, Bart
# Gosar, Paul A.
# Gottheimer, Josh
# Gowdy, Trey
# Graham, Gwen
# Graham, Lindsey
# Granger, Kay
# Grassley, Chuck
# Graves, Garret
# Graves, Sam
# Graves, Tom
# Grayson, Alan
# Green, Al
# Green, Gene
# Green, Mark E.
# Gregg, Judd
# Griffin, Tim
# Griffith, H. Morgan
# Griffith, Parker
# Grijalva, Raul M.
# Grimm, Michael G.
# Grothman, Glenn
# Guest, Michael
# Guinta, Frank C.
# Guthrie, Brett
# Gutierrez, Luis V.
# Haaland, Debra A.
# Hagan, Kay R.
# Hagedorn, Jim
# Hahn, Janice
# Hall, John J.
# Hall, Ralph M.
# Halvorson, Deborah L.
# Hanabusa, Colleen
# Handel, Karen C.
# Hanna, Richard L.
# Harder, Josh
# Hardy, Cresent
# Hare, Phil
# Harkin, Tom
# Harman, Jane
# Harper, Gregg
# Harris, Andy
# Harris, Kamala D.
# Hartzler, Vicky
# Hassan, Margaret Wood
# Hastings, Alcee L.
# Hastings, Doc
# Hatch, Orrin G.
# Hawley, Josh
# Hayes, Jahana
# Hayworth, Nan A. S.
# Heck, Denny
# Heck, Joseph J.
# Heinrich, Martin
# Heitkamp, Heidi
# Heller, Dean
# Hensarling, Jeb
# Herger, Wally
# Hern, Kevin
# Herrera Beutler, Jaime
# Herseth Sandlin, Stephanie
# Hice, Jody B.
# Higgins, Brian
# Higgins, Clay
# Hill, Baron P.
# Hill, J. French
# Hill, Katie
# Himes, James A.
# Hinchey, Maurice D.
# Hinojosa, Ruben
# Hirono, Mazie K.
# Hochul, Kathleen C.
# Hodes, Paul W.
# Hoekstra, Peter
# Hoeven, John
# Holden, Tim
# Holding, George
# Hollingsworth, Trey
# Holt, Rush
# Honda, Michael M.
# Horn, Kendra S.
# Horsford, Steven
# Houlahan, Chrissy
# Hoyer, Steny H.
# Hudson, Richard
# Huelskamp, Tim
# Huffman, Jared
# Huizenga, Bill
# Hultgren, Randy
# Hunter, Duncan D.
# Hurd, Will
# Hurt, Robert
# Hutchison, Kay Bailey
# Hyde-Smith, Cindy
# Inglis, Bob
# Inhofe, James M.
# Inouye, Daniel K.
# Inslee, Jay
# Isakson, Johnny
# Israel, Steve
# Issa, Darrell E.
# Jackson Lee, Sheila
# Jackson, Jesse L., Jr.
# Jayapal, Pramila
# Jeffries, Hakeem S.
# Jenkins, Evan H.
# Jenkins, Lynn
# Johanns, Mike
# Johnson, Bill
# Johnson, Dusty
# Johnson, Eddie Bernice
# Johnson, Henry C. "Hank," Jr.
# Johnson, Mike
# Johnson, Ron
# Johnson, Sam
# Johnson, Tim
# Johnson, Timothy V.
# Jolly, David W.
# Jones, Brenda
# Jones, Doug
# Jones, Walter B., Jr.
# Jordan, Jim
# Joyce, David P.
# Joyce, John
# Kagen, Steve
# Kaine, Tim
# Kanjorski, Paul E.
# Kaptur, Marcy
# Katko, John
# Kaufman, Edward E.
# Keating, William R.
# Keller, Fred
# Kelly, Mike
# Kelly, Robin L.
# Kelly, Trent
# Kennedy, Edward M.
# Kennedy, John
# Kennedy, Joseph P., III
# Kennedy, Patrick J.
# Kerry, John F.
# Khanna, Ro
# Kihuen, Ruben J.
# Kildee, Dale E.
# Kildee, Daniel T.
# Kilmer, Derek
# Kilpatrick, Carolyn C.
# Kilroy, Mary Jo
# Kim, Andy
# Kind, Ron
# King, Angus S., Jr.
# King, Peter T.
# King, Steve
# Kingston, Jack
# Kinzinger, Adam
# Kirk, Mark Steven
# Kirk, Paul Grattan, Jr.
# Kirkpatrick, Ann
# Kissell, Larry
# Klein, Ron
# Kline, John
# Klobuchar, Amy
# Knight, Stephen
# Kohl, Herb
# Kosmas, Suzanne M.
# Kratovil, Frank,  Jr.
# Krishnamoorthi, Raja
# Kucinich, Dennis J.
# Kuster, Ann M.
# Kustoff, David
# Kyl, Jon
# Labrador, Raul R.
# LaHood, Darin
# LaMalfa, Doug
# Lamb, Conor
# Lamborn, Doug
# Lance, Leonard
# Landrieu, Mary L.
# Landry, Jeffrey M.
# Langevin, James R.
# Lankford, James
# Larsen, Rick
# Larson, John B.
# Latham, Tom
# LaTourette, Steven C.
# Latta, Robert E.
# Lautenberg, Frank R.
# Lawrence, Brenda L.
# Lawson, Al, Jr.
# Leahy, Patrick J.
# Lee, Barbara
# Lee, Christopher J.
# Lee, Mike
# Lee, Susie
# LeMieux, George S.
# Lesko, Debbie
# Levin, Andy
# Levin, Carl
# Levin, Mike
# Levin, Sander M.
# Lewis, Jason
# Lewis, Jerry
# Lewis, John
# Lieberman, Joseph I.
# Lieu, Ted
# Lincoln, Blanche L.
# Linder, John
# Lipinski, Daniel
# LoBiondo, Frank A.
# Loebsack, David
# Loeffler, Kelly
# Lofgren, Zoe
# Long, Billy
# Loudermilk, Barry
# Love, Mia B.
# Lowenthal, Alan S.
# Lowey, Nita M.
# Lucas, Frank D.
# Luetkemeyer, Blaine
# Lugar, Richard G.
# Lujan Grisham, Michelle
# Lujan, Ben Ray
# Lummis, Cynthia M.
# Lungren, Daniel E.
# Luria, Elaine G.
# Lynch, Stephen F.
# MacArthur, Thomas
# Mack, Connie
# Maffei, Daniel B.
# Malinowski, Tom
# Maloney, Carolyn B.
# Maloney, Sean Patrick
# Manchin, Joe, III
# Manzullo, Donald A.
# Marchant, Kenny
# Marino, Tom
# Markey, Betsy
# Markey, Edward J.
# Marshall, Jim
# Marshall, Roger W.
# Martinez, Mel
# Massa, Eric J. J.
# Massie, Thomas
# Mast, Brian J.
# Matheson, Jim
# Matsui, Doris O.
# McAdams, Ben
# McAllister, Vance M.
# McBath, Lucy
# McCain, John
# McCarthy, Carolyn
# McCarthy, Kevin
# McCaskill, Claire
# McCaul, Michael T.
# McClintock, Tom
# McCollum, Betty
# McConnell, Mitch
# McCotter, Thaddeus G.
# McCrery, Jim
# McDermott, Jim
# McEachin, A. Donald
# McGovern, James P.
# McHenry, Patrick T.
# McHugh, John M.
# McIntyre, Mike
# McKeon, Howard P. "Buck"
# McKinley, David B.
# McMahon, Michael E.
# McMorris Rodgers, Cathy
# McNerney, Jerry
# McSally, Martha
# Meadows, Mark
# Meehan, Patrick
# Meek, Kendrick B.
# Meeks, Gregory W.
# Melancon, Charlie
# Menendez, Robert
# Meng, Grace
# Merkley, Jeff
# Messer, Luke
# Meuser, Daniel
# Mica, John L.
# Michaud, Michael H.
# Mikulski, Barbara A.
# Miller, Brad
# Miller, Candice S.
# Miller, Carol D.
# Miller, Gary G.
# Miller, George
# Miller, Jeff
# Minnick, Walter
# Mitchell, Harry E.
# Mitchell, Paul
# Mollohan, Alan B.
# Moolenaar, John R.
# Mooney, Alexander X.
# Moore, Dennis
# Moore, Gwen
# Moran, James P.
# Moran, Jerry
# Morelle, Joseph D.
# Moulton, Seth
# Mucarsel-Powell, Debbie
# Mullin, Markwayne
# Mulvaney, Mick
# Murkowski, Lisa
# Murphy, Christopher
# Murphy, Gregory
# Murphy, Patrick
# Murphy, Patrick J.
# Murphy, Scott
# Murphy, Stephanie N.
# Murphy, Tim
# Murray, Patty
# Murtha, John P.
# Myrick, Sue Wilkins
# Nadler, Jerrold
# Napolitano, Grace F.
# Neal, Richard E.
# Negrete McLeod, Gloria
# Neguse, Joe
# Nelson, Ben
# Nelson, Bill
# Neugebauer, Randy
# Newhouse, Dan
# Noem, Kristi L.
# Nolan, Richard M.
# Norcross, Donald
# Norman, Ralph
# Delegate Norton, Eleanor Holmes
# Nugent, Richard B.
# Nunes, Devin
# Nunnelee, Alan
# Nye, Glenn C.
# O'Halleran, Tom
# O'Rourke, Beto
# Oberstar, James L.
# Obey, David R.
# Ocasio-Cortez, Alexandria
# Olson, Pete
# Olver, John W.
# Omar, Ilhan
# Ortiz, Solomon P.
# Owens, William L.
# Palazzo, Steven M.
# Pallone, Frank, Jr.
# Palmer, Gary J.
# Panetta, Jimmy
# Pappas, Chris
# Pascrell, Bill, Jr.
# Pastor, Ed
# Paul, Rand
# Paul, Ron
# Paulsen, Erik
# Payne, Donald M.
# Payne, Donald M., Jr.
# Pearce, Stevan
# Pelosi, Nancy
# Pence, Greg
# Pence, Mike
# Perdue, David
# Perlmutter, Ed
# Perriello, Thomas S.P.
# Perry, Scott
# Peters, Gary C.
# Peters, Scott H.
# Peterson, Collin C.
# Petri, Thomas E.
# Phillips, Dean
# Pierluisi, Pedro R.
# Pingree, Chellie
# Pittenger, Robert
# Pitts, Joseph R.
# Delegate Plaskett, Stacey E.
# Platts, Todd Russell
# Pocan, Mark
# Poe, Ted
# Poliquin, Bruce
# Polis, Jared
# Pomeroy, Earl
# Pompeo, Mike
# Porter, Katie
# Portman, Rob
# Posey, Bill
# Pressley, Ayanna
# Price, David E.
# Price, Tom
# Pryor, Mark L.
# Putnam, Adam H.
# Quayle, Benjamin
# Quigley, Mike
# Radanovich, George
# Radel, Trey
# Delegate Radewagen, Aumua Amata Coleman
# Rahall, Nick J., II
# Rangel, Charles B.
# Raskin, Jamie
# Ratcliffe, John
# Reed, Jack
# Reed, Tom
# Rehberg, Denny
# Reichert, David G.
# Reid, Harry
# Renacci, James B.
# Reschenthaler, Guy
# Reyes, Silvestre
# Ribble, Reid J.
# Rice, Kathleen M.
# Rice, Tom
# Richardson, Laura
# Richmond, Cedric L.
# Rigell, E. Scott
# Riggleman, Denver
# Risch, James E.
# Rivera, David
# Roberts, Pat
# Roby, Martha
# Rockefeller, John D., IV
# Rodriguez, Ciro D.
# Roe, David P.
# Rogers, Harold
# Rogers, Mike D.
# Rogers, Mike J.
# Rohrabacher, Dana
# Rokita, Todd
# Romney, Mitt
# Rooney, Francis
# Rooney, Thomas J.
# Ros-Lehtinen, Ileana
# Rose, John W.
# Rose, Max
# Rosen, Jacky
# Roskam, Peter J.
# Ross, Dennis A.
# Ross, Mike
# Rothfus, Keith J.
# Rothman, Steven R.
# Rouda, Harley
# Rounds, Mike
# Rouzer, David
# Roy, Chip
# Roybal-Allard, Lucille
# Royce, Edward R.
# Rubio, Marco
# Ruiz, Raul
# Runyan, Jon
# Ruppersberger, C. A. Dutch
# Rush, Bobby L.
# Russell, Steve
# Rutherford, John H.
# Ryan, Paul D.
# Ryan, Tim
# Delegate Sablan, Gregorio Kilili Camacho
# Salazar, John T.
# Salazar, Ken
# Salmon, Matt
# Delegate San Nicolas, Michael F. Q.
# Sanchez, Linda T.
# Sanchez, Loretta
# Sanders, Bernard
# Sanford, Mark
# Sarbanes, John P.
# Sasse, Ben
# Scalise, Steve
# Scanlon, Mary Gay
# Schakowsky, Janice D.
# Schatz, Brian
# Schauer, Mark H.
# Schiff, Adam B.
# Schilling, Robert T.
# Schmidt, Jean
# Schneider, Bradley Scott
# Schock, Aaron
# Schrader, Kurt
# Schrier, Kim
# Schumer, Charles E.
# Schwartz, Allyson Y.
# Schweikert, David
# Scott, Austin
# Scott, David
# Scott, Rick
# Scott, Robert C. "Bobby"
# Scott, Tim
# Sensenbrenner, F. James, Jr.
# Serrano, Jose E.
# Sessions, Jeff
# Sessions, Pete
# Sestak, Joe
# Sewell, Terri A.
# Shadegg, John B.
# Shaheen, Jeanne
# Shalala, Donna E.
# Shea-Porter, Carol
# Shelby, Richard C.
# Sherman, Brad
# Sherrill, Mikie
# Shimkus, John
# Shuler, Heath
# Shuster, Bill
# Simpson, Michael K.
# Sinema, Kyrsten
# Sires, Albio
# Skelton, Ike
# Slaughter, Louise McIntosh
# Slotkin, Elissa
# Smith, Adam
# Smith, Adrian
# Smith, Christopher H.
# Smith, Jason
# Smith, Lamar
# Smith, Tina
# Smucker, Lloyd
# Snowe, Olympia J.
# Snyder, Vic
# Solis, Hilda L.
# Soto, Darren
# Souder, Mark E.
# Southerland, Steve II
# Space, Zachary T.
# Spanberger, Abigail Davis
# Spano, Ross
# Specter, Arlen
# Speier, Jackie
# Spratt, John M., Jr.
# Stabenow, Debbie
# Stanton, Greg
# Stark, Fortney Pete
# Stauber, Pete
# Stearns, Cliff
# Stefanik, Elise M.
# Steil, Bryan
# Steube, W. Gregory
# Stevens, Haley M.
# Stewart, Chris
# Stivers, Steve
# Stockman, Steve
# Strange, Luther
# Stupak, Bart
# Stutzman, Marlin A.
# Sullivan, Dan
# Sullivan, John
# Suozzi, Thomas R.
# Sutton, Betty
# Swalwell, Eric
# Takai, Mark
# Takano, Mark
# Tanner, John S.
# Tauscher, Ellen O.
# Taylor, Gene
# Taylor, Scott
# Taylor, Van
# Teague, Harry
# Tenney, Claudia
# Terry, Lee
# Tester, Jon
# Thompson, Bennie G.
# Thompson, Glenn
# Thompson, Mike
# Thornberry, Mac
# Thune, John
# Tiahrt, Todd
# Tiberi, Patrick J.
# Tierney, John F.
# Tillis, Thom
# Timmons, William R. IV
# Tipton, Scott  R.
# Titus, Dina
# Tlaib, Rashida
# Tonko, Paul
# Toomey, Pat
# Torres Small, Xochitl
# Torres, Norma J.
# Towns, Edolphus
# Trahan, Lori
# Trone, David J.
# Trott, David A.
# Tsongas, Niki
# Turner, Michael R.
# Turner, Robert L.
# Udall, Mark
# Udall, Tom
# Underwood, Lauren
# Upton, Fred
# Valadao, David G.
# Van Drew, Jefferson
# Van Hollen, Chris
# Vargas, Juan
# Veasey, Marc A.
# Vela, Filemon
# Velazquez, Nydia M.
# Visclosky, Peter J.
# Vitter, David
# Voinovich, George V.
# Wagner, Ann
# Walberg, Tim
# Walden, Greg
# Walker, Mark
# Walorski, Jackie
# Walsh, Joe
# Walsh, John E.
# Walters, Mimi
# Waltz, Michael
# Walz, Timothy J.
# Wamp, Zach
# Warner, Mark R.
# Warren, Elizabeth
# Wasserman Schultz, Debbie
# Waters, Maxine
# Watkins, Steve
# Watson Coleman, Bonnie
# Watson, Diane E.
# Watt, Melvin L.
# Waxman, Henry A.
# Webb, Jim
# Weber, Randy K., Sr.
# Webster, Daniel
# Weiner, Anthony D.
# Welch, Peter
# Wenstrup, Brad R.
# West, Allen B.
# Westerman, Bruce
# Westmoreland, Lynn A.
# Wexler, Robert
# Wexton, Jennifer
# Whitehouse, Sheldon
# Whitfield, Ed
# Wicker, Roger F.
# Wild, Susan
# Williams, Roger
# Wilson, Charles A.
# Wilson, Frederica S.
# Wilson, Joe
# Wittman, Robert J.
# Wolf, Frank R.
# Womack, Steve
# Woodall, Rob
# Woolsey, Lynn C.
# Wright, Ron
# Wu, David
# Wyden, Ron
# Yarmuth, John A.
# Yoder, Kevin
# Yoho, Ted S.
# Young, C. W. Bill
# Young, David
# Young, Don
# Young, Todd
# Zeldin, Lee M.
# Zinke, Ryan K.

# %%
#Quick look at the data
congress_member_info
# Out:
#                     name                                                url  \
# 0      Abercrombie, Neil  https://www.congress.gov/member/neil-abercromb...
# 1      Abercrombie, Neil  https://www.congress.gov/member/neil-abercromb...
# 2     Abraham, Ralph Lee  https://www.congress.gov/member/ralph-abraham/...
# 3      Ackerman, Gary L.  https://www.congress.gov/member/gary-ackerman/...
# 4      Ackerman, Gary L.  https://www.congress.gov/member/gary-ackerman/...
# ...                  ...                                                ...
# 1333          Young, Don  https://www.congress.gov/member/don-young/Y000033
# 1334         Young, Todd  https://www.congress.gov/member/todd-young/Y00...
# 1335         Young, Todd  https://www.congress.gov/member/todd-young/Y00...
# 1336      Zeldin, Lee M.  https://www.congress.gov/member/lee-zeldin/Z00...
# 1337      Zinke, Ryan K.  https://www.congress.gov/member/ryan-zinke/Z00...
#
#            party      state  district chamber start   end
# 0     Democratic     Hawaii         1   House  1991  2011
# 1     Democratic     Hawaii         1   House  1985  1987
# 2     Republican  Louisiana         5   House  2015   inf
# 3     Democratic   New York         5   House  1993  2013
# 4     Democratic   New York         7   House  1983  1993
# ...          ...        ...       ...     ...   ...   ...
# 1333  Republican     Alaska  At Large   House  1973   inf
# 1334  Republican    Indiana         0  Senate  2017   inf
# 1335  Republican    Indiana         9   House  2011  2017
# 1336  Republican   New York         1   House  2015   inf
# 1337  Republican    Montana  At Large   House  2015  2017
#
# [1338 rows x 8 columns]

# %%
# Finally save what we scraped
congress_member_info.to_csv("congress_111_116.csv")
